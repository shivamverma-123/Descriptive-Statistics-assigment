# %% [markdown]
# #Descriptive Statistics
#
# Easy Level
#
# Q1: Understanding Central Tendency (Easy)
#
# A bakery tracks the daily sales of muffins (in dozens) over a week: [10, 12, 11, 15, 14, 13, 12].
# What is the most representative value of their weekly sales, and why?
#
# ans:Daily muffin sales (in dozens):
# [10, 12, 11, 15, 14, 13, 12]
#
# mean=10+12+11+15+14+13+12,this all divde by 7
#
# = 87/7= 12.43dozen(approx)
#
# Q2. Mean in Real Life (Easy)
#
# A teacher records the marks of her students in a short quiz: [12, 15, 14, 16, 18, 20, 19].
# What is the mean score, and what does it tell us about the class’s performance?
#
# Ans:Marks:
#
# [12, 15, 14, 16, 18, 20, 19]
#
# mean= 12+15+14+16+18+20+19/7
#
# =114/7= 16.28
#
# Mean score = 16.28 marks (approx)
#
# Q3.Mode in Real Life (Easy)
#
# A store records the shoe sizes sold in one day: [7, 8, 9, 8, 8, 10, 7, 9].
# What is the mode, and why is This information useful for the store manager?.
#
# Ans:
#
# STEP-1
#
#  Shoe size sold [7, 8, 9, 8, 8, 10, 7, 9].
#
# find the mode
#
# count each side
#
# 7-2 times
#
# 8-3 times
#
# 9-2 times
#
# 10-1 times
#
# MODE=8 (because it appears the most: 3 times).
#
# STEP-2
#
# Why is this information useful for the store manager?
#
# Knowing the mode helps the store manager because:
#
#  I) Size 8 is in highest demand.
#
# II)The manager can stock more size 8 shoes to avoid running out.
#
# III)It improves inventory planning and reduces overstock of less popular sizes.
#
# IV)Helps in making better purchasing and sales decisions.
#
# MEDIUM LEVEL:
#
# Q4: Median in Real Life (Medium)
# A car dealer notes the prices of used cars: [$8,000,$9,500, $10,200, $11,000, $50,000].
# Why is the median a better measure than the mean in this case? Calculate the median.
#
# Ans:Prices of used cars:
#
# [$8,000, $9,500, $10,200, $11,000, $50,000]
#
# step-1
#
# Why is the median better than the mean?
#
# The data has an outlier: $50,000, which is much higher than the others.
#
# This outlier will pull the mean up, making the average price look much higher than what most cars actually cost.
#
# The median is not affected by extreme values.
#
# So the median gives a more realistic central value of typical used car prices.
#
# step-2:
#
# Arrange the data (already in order):
#
# 8,000
# 9,500
# 10,200
# 11,000
# 50,000
#
# step-3:
#
# find the median
#
# Since there are 5 values, the median is the middle value (3rd value):
#
# Median= 10,200.
#
# Q5.Dispersion Introduction (Medium)
#
# A student times how long it takes to finish a puzzle each day: [25, 30, 27, 35, 40].
# What does the range tell us about the variation in the student’s puzzle-solving time?
#
# Ans: Puzzle completion times (in minutes):
#
# [25, 30, 27, 35, 40]
#
# Step 1:
#
# Calculate the Range
#
# range= maximum value- minimum value
#
# Max = 40
# Min = 25
#
# range= 40-25=15
#
# Range=15 minutes
#
# Step 2:
#
# What does the range tell us?
#
# 1.The student’s puzzle-solving time varies by 15 minutes across the days.
#
# 2.This shows that the solving time is not very consistent — some days they finish quickly (25 min) and some days much slower (40 min).
#
# 3.A larger range means more variation, and here 15 minutes is a noticeable difference.
#
# Q6: Range in Action (Medium)
#
# A farmer records the weekly weight of harvested apples (kg): [100, 105, 98, 110, 120].
# Find the range. How can this help the farmer in planning his packaging?.
#
# Ans:Apple harvest weights (kg):
#
# [100, 105, 98, 110, 120]
#
# step-1:
#
# Calculate the range
#
# RANGE= MAXIMUM VALUE- MINIMUM VALUE
#
# MAX=120kg
# min= 98kg
#
# RANGE= MAX-MIN
#
# RANGE=120-98
#
# RANGE=22KG
#
# Step 2:
#
# How does this help the farmer in planning packaging?
#
# The range shows that apple harvests can vary by 22 kg per week.
# This helps the farmer:
#
# 1.Estimate packaging needs more accurately.
# 2.If he knows the weekly harvest might fluctuate by up to 22 kg, he can keep extra bags or boxes ready.
#
# 3.Avoid running out of packaging material.
#
# 4.Prevent over-ordering packaging, saving cost.
#
# 5.Plan storage space properly, since some weeks produce much more apples.
#
# Q7. Variance for Decision-Making (Medium)
#
# Two delivery companies track delivery delays (in minutes).
#
# Company A: variance = 6
#
# Company B: variance = 15
#  Which company is more consistent, and why?
#
# Ans:Given:
#
# Company A variance = 6
#
# Company B variance = 15
#
#  Which company is more consistent?
#
# Company A is more consistent.
#
#  Why?
#
# 1.Variance measures how spread out (or inconsistent) the data is.
#
# 2.A lower variance means the delivery times stay closer to the average.
#
# 3.A higher variance means more fluctuation and bigger delays.
#
# Since 6 < 15, Company A has less variation in delivery delays → more reliability and consistency.
#
# Hard Level
#
# Q8: Standard Deviation in Context (Hard)
#
# A finance student compares the daily price fluctuations of two cryptocurrencies.
#
# Coin A: standard deviation = $30
#
# Coin B: standard deviation = $120
#  Which coin is riskier to invest in, and why?
#
# Ans: Standard deviation tells how much the price moves up and down from its average.
#
#
# Higher standard deviation = bigger price swings = more risk.
#
#
# Given:
#
#
# Coin A SD = $30
#
#
# Coin B SD = $120
#
#
# Since $120 is much higher than $30, Coin B's price fluctuates more, meaning its value can rise or fall sharply.
# That makes Coin B more volatile and therefore riskier for investors.
#
# Q9: Combining Measures (Hard)
#
# A.family records their monthly electricity usage (in kWh): [400, 420, 390, 450, 410].
#
# Find the mean and standard deviation. What do these values together tell you about the family’s energy use
# pattern?
#
# Ans:Let's find the mean and standard deviation step by step.
#
# Step-1: Mean Electricity Usage
#
# Data: [400, 420, 390, 450, 410]
#
# MEAN=
#
#     400+420+390+450+410/5
#
#     = 2070/5
#
#     = 414 KWH
#
# MEAN= 414KWH
#
# 2.Standard Deviation (Population SD)
#
# Step 1: Find deviations from the mean
#
# 400 − 414 = −14
#
# 420 − 414 = 6
#
# 390 − 414 = −24
#
# 450 − 414 = 36
#
# 410 − 414 = −4
#
#
# Step 2: Square each deviation
#
# (−14)² = 196
#
# 6² = 36
#
# (−24)² = 576
#
# 36² = 1296
#
# (−4)² = 16
#
# Sum of squares =
# 196
# +
# 36
# +
# 576
# +
# 1296
# +
# 16
# =
# 2120
# 196+36+576+1296+16=2120
#
# Step 3: Variance
# Variance
# =
# 2120
# 5
# =
# 424
# Variance=
# 5
# 2120
# 	​
#
# =424
#
# Step 4: Standard Deviation
# SD
# =
# 424
# ≈
# 20.6
#  kWh
# SD=
# 424
# 	​
#
# ≈20.6 kWh
#
# Standard Deviation ≈ 20.6 kWh.
#
# 3.What do these values tell you?
# Mean = 414 kWh
#
# → The family usually consumes around 414 kWh per month.
#
# Standard Deviation ≈ 20.6 kWh
#
# → Their monthly usage doesn’t change much — only about 20 kWh above or below the average.
#
# Combined Interpretation
#
# The family’s electricity usage pattern is stable and consistent.
# There are no big spikes in consumption, indicating predictable monthly usage.
#
# Q10: Practical Application (Hard)
#
# A basketball player’s points in 8 games are recorded: [15, 18, 20, 22, 25, 17, 19, 21].
# Find the mean, median, mode, range, and standard deviation. What insights can these measures provide
# about the player’s scoring performance?.
#
# Ans:Let’s calculate ALL statistical measures step by step.
#
# Data:
# [15, 18, 20, 22, 25, 17, 19, 21]
#
# 1.Mean (Average)
#
# Mean= 15+18+20+22+25+17+19+21/8
#
# =157/8
#
# =19.625
#
# MEAN=19.63 (APPROX)
#
# 2.MEDIAN (Middle value)
#
#  Sort the data: [15, 17, 18, 19, 20, 21, 22, 25]
#
# Since there are 8 numbers (even count):
#
# median= 19+20/2=19.5
#
# MEDIAN=19.5 POINTS
#
# 3.MODE (Most Frequent Value)
#
# All values appear once → No mode
#
# MODE = None
#
# 4.RANGE
#
# RANGE= MAXIMUM VALUE- MINIMUM VALUE
#
# R= 25-15=10
#
# RANGE= 10point
#
# 5. Standard Deviation (Population SD)
#
# Mean = 19.625
#
# Find deviations and square them:
#
# | Value | Deviation (x − mean) | Square  |
# | ----- | -------------------- | ------- |
# | 15    | -4.625               | 21.3906 |
# | 17    | -2.625               | 6.8906  |
# | 18    | -1.625               | 2.6406  |
# | 19    | -0.625               | 0.3906  |
# | 20    | 0.375                | 0.1406  |
# | 21    | 1.375                | 1.8906  |
# | 22    | 2.375                | 5.6406  |
# | 25    | 5.375                | 28.8906 |
#
# Sum of squares ≈ 67.875
#
# Variance =
#
# 67.875
# 8
# =
# 8.484
# 8
# 67.875
# 	​
#
# =8.484
#
# Standard deviation =
#
# 8.484
# ≈
# 2.91
# 8.484
# 	​
#
# ≈2.91
#
# Standard Deviation ≈ 2.91 points
#
# Final Statistical Summary:
#
# | Measure            | Value  |
# | ------------------ | ------ |
# | Mean               | 19.63  |
# | Median             | 19.5   |
# | Mode               | None   |
# | Range              | 10     |
# | Standard Deviation | ≈2.91  |
#
# STEP-2:
#
# Insights About the Player’s Scoring Performance
# 1. Very Consistent Scoring
#
# SD ≈ 2.9 is small
# → The player scores close to the average almost every game.
#
# 2. Average Performance
#
# Mean ≈ 19.6 points
# → The player typically scores around 19–20 points per game.
#
# 3. Balanced Distribution
#
# Mean (19.63) and Median (19.5) are very close
# → Scores are symmetrical, not skewed.
#
# 4. No Mode
#
# → The player doesn’t repeat the exact same score often, but still stays in the same range.
#
# 5. Range = 10
#
# → The difference between the lowest (15) and highest (25) is moderate.
# Not too much variation → steady performance.
